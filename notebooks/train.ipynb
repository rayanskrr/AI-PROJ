# %% [markdown]
# <a href="https://colab.research.google.com/github/rayanskrr/AI-PROJ/blob/main/notebooks/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

ckpt_dir = '/content/drive/MyDrive/hieroglyph_ckpts'
os.makedirs(ckpt_dir, exist_ok=True)
print(f"Checkpoint directory ready at: {ckpt_dir}")

if not os.path.exists('/content/AI-PROJ'):
    # !git clone https://github.com/rayanskrr/AI-PROJ.git /content/AI-PROJ
else:
    print("Repo already cloned.")

# !pip install -r /content/AI-PROJ/requirements.txt

if not os.path.exists('/content/EgyptianHieroglyphicText'):
    # !git clone https://github.com/rfuentesfe/EgyptianHieroglyphicText.git /content/EgyptianHieroglyphicText
else:
    print("Dataset already cloned.")

print("Environment fully set up!")
# Out:
# Cloning into '/content/AI-PROJ'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17 (delta 2), reused 7 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 6.64 KiB | 3.32 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
